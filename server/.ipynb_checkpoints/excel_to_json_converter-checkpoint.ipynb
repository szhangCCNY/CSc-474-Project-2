# %%
import os
print(os.getcwd())
# the files will be in this directory
# Out:
# /Users/solomonzhang/CSc447/CSc-474-Project-2/server

# %%
import pandas as pd

# %%
# excel sheets for SWOT

excelSheets = ["Strength AnalysisData.xlsx", "Weakness Analysis Data.xlsx", "Opportunity Analysis Data.xlsx", "Threat Analysis Data.xlsx"]

# corresponding json names
# name of each json files
jsonNames = ["strength.json", "weakness.json", "opportunity.json", "threat.json"]

# %%
def getMinProbAdjust(estVal, minProb):
    if pd.notna(minProb):
        return minProb * (estVal/100)
    else:
        return 0
    
def getMaxProbAdjust(estVal, maxProb):
    if pd.notna(maxProb):
        return maxProb * (estVal/100)
    else:
        return 0
    
def getAvgProbAdjust(minAdjust, maxAdjust):
    if (pd.notna(minAdjust) and pd.notna(maxAdjust)):
        return (minAdjust + maxAdjust) / 2
    else:
        return 0

def getRealProbAdjust(estVal, realProb):
    if (pd.notna(estVal) and pd.notna(realProb)):
        return estVal*(realProb/100)
    else:
        return 0

def get3PointProbAdjust(estVal, threePointProb):
    if (pd.notna(estVal) and pd.notna(maxAdjust)):
        return estVal * (threePointProb/ 100)
    else:
        return 0

def getPertAdjust(estVal, pertProb):
    if (pd.notna(estVal) and pd.notna(pertProb)):
        return estVal * (pertProb/ 100)
    else:
        return 0

# %%
# for each excel sheet write to json
cols = ["EST. VALUE IN CURRENCY", "MIN PROB  %", "REALISTIC PROB  %", "MAX PROB %", "STATS PROB % ( 3 POINT BASED)",
       "STATS PROB % (PERT BASED)", "MIN PROB ADJUSTED VALUE", "MAX PROB ADJUSTED VALUE", "AVERAGE PROB ADJUSTED VALUE",
       "REALISTIC PROB ADJUSTED VALUE", "3 POINT BASED PROB ADJUSTED VALUE", "PERT BASED PROB ADJUSTED VALUE"]


for i in range(len(excelSheets)):
    df = pd.read_excel(excelSheets[i])
#     print(df.info())
    # can only compute if you have this
    process_df = pd.DataFrame()
    for index, row in df.iterrows():
        est_val = row["EST. VALUE IN CURRENCY"]
        if pd.notna(est_val):
            min_prob = row["MIN PROB  %"]
            real_prob = row["REALISTIC PROB  %"]
            max_prob = row["MAX PROB %"]
            threePoint_prob = row["STATS PROB % ( 3 POINT BASED)"]
            pert_prob = row["STATS PROB % (PERT BASED)"]

            minAdjust = getMinProbAdjust(est_val, min_prob)
            maxAdjust = getMaxProbAdjust(est_val, max_prob)
            avgAdjust = getAvgProbAdjust(minAdjust, maxAdjust)
            realAdjust = getRealProbAdjust(est_val, real_prob)
            threePointAdjust = get3PointProbAdjust(est_val, threePoint_prob)
            pertAdjust = getPertAdjust(est_val, pert_prob)

            # save to df
            row["MIN PROB ADJUSTED VALUE"] = minAdjust
            row["MAX PROB ADJUSTED VALUE"] = maxAdjust
            row["AVERAGE PROB ADJUSTED VALUE"] = avgAdjust
            row["REALISTIC PROB ADJUSTED VALUE"] = realAdjust
            row["3 POINT BASED PROB ADJUSTED VALUE"] = threePointAdjust
            row["PERT BASED PROB ADJUSTED VALUE"] = pertAdjust
        # check column if NaN -> if this is the case set to 0
        for col in cols:
            if pd.isna(row[col]):
                row[col] = 0
        process_df = process_df.append(row)
        
#         process_df.head()
    print(process_df.info())
    with open("json_files/" + jsonNames[i], 'w') as f:
        f.write(process_df.to_json(orient='records', indent=2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 0 to 2
# Data columns (total 16 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   CATEGORY                           3 non-null      object
#  1   FACTOR TYPE                        3 non-null      object
#  2   Sl #                               3 non-null      float64
#  3   PARAM NAME                         3 non-null      object
#  4   EST. VALUE IN CURRENCY             3 non-null      float64
#  5   MIN PROB  %                        3 non-null      float64
#  6   REALISTIC PROB  %                  3 non-null      float64
#  7   MAX PROB %                         3 non-null      float64
#  8   STATS PROB % ( 3 POINT BASED)      3 non-null      float64
#  9   STATS PROB % (PERT BASED)          3 non-null      float64
#  10  MIN PROB ADJUSTED VALUE            3 non-null      float64
#  11  MAX PROB ADJUSTED VALUE            3 non-null      float64
#  12  AVERAGE PROB ADJUSTED VALUE        3 non-null      float64
#  13  REALISTIC PROB ADJUSTED VALUE      3 non-null      float64
#  14  3 POINT BASED PROB ADJUSTED VALUE  3 non-null      float64
#  15  PERT BASED PROB ADJUSTED VALUE     3 non-null      float64
# dtypes: float64(13), object(3)
# memory usage: 408.0+ bytes
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 0 to 9
# Data columns (total 16 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   CATEGORY                           10 non-null     object
#  1   FACTOR TYPE                        10 non-null     object
#  2   Sl #                               10 non-null     float64
#  3   PARAM NAME                         10 non-null     object
#  4   EST. VALUE IN CURRENCY             10 non-null     float64
#  5   MIN PROB  %                        10 non-null     float64
#  6   REALISTIC PROB  %                  10 non-null     float64
#  7   MAX PROB %                         10 non-null     float64
#  8   STATS PROB % ( 3 POINT BASED)      10 non-null     float64
#  9   STATS PROB % (PERT BASED)          10 non-null     float64
#  10  MIN PROB ADJUSTED VALUE            10 non-null     float64
#  11  MAX PROB ADJUSTED VALUE            10 non-null     float64
#  12  AVERAGE PROB ADJUSTED VALUE        10 non-null     float64
#  13  REALISTIC PROB ADJUSTED VALUE      10 non-null     float64
#  14  3 POINT BASED PROB ADJUSTED VALUE  10 non-null     float64
#  15  PERT BASED PROB ADJUSTED VALUE     10 non-null     float64
# dtypes: float64(13), object(3)
# memory usage: 1.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 0 to 2
# Data columns (total 16 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   CATEGORY                           3 non-null      object
#  1   FACTOR TYPE                        3 non-null      object
#  2   Sl #                               3 non-null      float64
#  3   PARAM NAME                         3 non-null      object
#  4   EST. VALUE IN CURRENCY             3 non-null      float64
#  5   MIN PROB  %                        3 non-null      float64
#  6   REALISTIC PROB  %                  3 non-null      float64
#  7   MAX PROB %                         3 non-null      float64
#  8   STATS PROB % ( 3 POINT BASED)      3 non-null      float64
#  9   STATS PROB % (PERT BASED)          3 non-null      float64
#  10  MIN PROB ADJUSTED VALUE            3 non-null      float64
#  11  MAX PROB ADJUSTED VALUE            3 non-null      float64
#  12  AVERAGE PROB ADJUSTED VALUE        3 non-null      float64
#  13  REALISTIC PROB ADJUSTED VALUE      3 non-null      float64
#  14  3 POINT BASED PROB ADJUSTED VALUE  3 non-null      float64
#  15  PERT BASED PROB ADJUSTED VALUE     3 non-null      float64
# dtypes: float64(13), object(3)
# memory usage: 408.0+ bytes
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 0 to 2
# Data columns (total 16 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   CATEGORY                           3 non-null      object
#  1   FACTOR TYPE                        3 non-null      object
#  2   Sl #                               3 non-null      float64
#  3   PARAM NAME                         3 non-null      object
#  4   EST. VALUE IN CURRENCY             3 non-null      float64
#  5   MIN PROB  %                        3 non-null      float64
#  6   REALISTIC PROB  %                  3 non-null      float64
#  7   MAX PROB %                         3 non-null      float64
#  8   STATS PROB % ( 3 POINT BASED)      3 non-null      float64
#  9   STATS PROB % (PERT BASED)          3 non-null      float64
#  10  MIN PROB ADJUSTED VALUE            3 non-null      float64
#  11  MAX PROB ADJUSTED VALUE            3 non-null      float64
#  12  AVERAGE PROB ADJUSTED VALUE        3 non-null      float64
#  13  REALISTIC PROB ADJUSTED VALUE      3 non-null      float64
#  14  3 POINT BASED PROB ADJUSTED VALUE  3 non-null      float64
#  15  PERT BASED PROB ADJUSTED VALUE     3 non-null      float64
# dtypes: float64(13), object(3)
# memory usage: 408.0+ bytes
# None
